# %% [markdown]
# # Exploring and Transforming JSON Schemas

# %% [markdown]
# # Introduction
#
# In this lesson, you'll formalize how to explore a JSON file whose structure and schema is unknown to you. This often happens in practice when you are handed a file or stumble upon one with little documentation.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Explore unknown JSON schemas
# * Access and manipulate data inside a JSON file
# * Convert JSON to alternative data formats

# %% [markdown]
# ## Loading the JSON file
#
# Load the data from the file disease_data.json.

# %%
import json
data = json.load(open('disease_data.json'))
type(data)
# Out:
# dict

# %% [markdown]
# ## Explore the first and second levels of the schema hierarchy

# %%
data.keys()
print(data['meta']['view']['columns'][9]['name'])
#dict with column names
#print(len(data['data'][1]))
#list of lists, with each list corresponding to one row
# Out:
# YearEnd

# %% [markdown]
# ## Convert to a DataFrame
#
# Create a DataFrame from the JSON file. Be sure to retrive the column names for the dataframe. (Search within the 'meta' key of the master dictionary.) The DataFrame should include all 42 columns.

# %%
import pandas as pd

# %%
columns = [x['name'] for x in data['meta']['view']['columns']]
df = pd.DataFrame()
for n in range(0,len(columns)):
    df['{}'.format(columns[n])] = [data['data'][i][n] for i in range(0,len(data['data']))]
df.head()
# Out:
#    sid                                    id  position  created_at  \
# 0    1  FF49C41F-CE8D-46C4-9164-653B1227CF6F         1  1527194521
# 1    2  F4468C3D-340A-4CD2-84A3-DF554DFF065E         2  1527194521
# 2    3  65609156-A343-4869-B03F-2BA62E96AC19         3  1527194521
# 3    4  0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3         4  1527194521
# 4    5  D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B         5  1527194521
#
#   created_meta  updated_at updated_meta  meta YearStart YearEnd  \
# 0       959778  1527194521       959778  None      2016    2016
# 1       959778  1527194521       959778  None      2016    2016
# 2       959778  1527194521       959778  None      2016    2016
# 3       959778  1527194521       959778  None      2016    2016
# 4       959778  1527194521       959778  None      2016    2016
#
#          ...        LocationID TopicID QuestionID DataValueTypeID  \
# 0        ...                59     ALC     ALC2_2         CRDPREV
# 1        ...                01     ALC     ALC2_2         CRDPREV
# 2        ...                02     ALC     ALC2_2         CRDPREV
# 3        ...                04     ALC     ALC2_2         CRDPREV
# 4        ...                05     ALC     ALC2_2         CRDPREV
#
#   StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# 0                   OVERALL               OVR                      None
# 1                   OVERALL               OVR                      None
# 2                   OVERALL               OVR                      None
# 3                   OVERALL               OVR                      None
# 4                   OVERALL               OVR                      None
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0              None                      None              None
# 1              None                      None              None
# 2              None                      None              None
# 3              None                      None              None
# 4              None                      None              None
#
# [5 rows x 42 columns]

# %%
df.drop('sid',axis=1,inplace=True)
df.drop('id',axis=1,inplace=True)
df.drop('created_at',axis=1,inplace=True)
df.drop('created_meta',axis=1,inplace=True)
df.drop('updated_at',axis=1,inplace=True)
df.drop('updated_meta',axis=1,inplace=True)
df.drop('meta',axis=1,inplace=True)
df.head()
# Out:
#    position YearStart YearEnd LocationAbbr   LocationDesc DataSource    Topic  \
# 0         1      2016    2016           US  United States      BRFSS  Alcohol
# 1         2      2016    2016           AL        Alabama      BRFSS  Alcohol
# 2         3      2016    2016           AK         Alaska      BRFSS  Alcohol
# 3         4      2016    2016           AZ        Arizona      BRFSS  Alcohol
# 4         5      2016    2016           AR       Arkansas      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...     None             %
# 1  Binge drinking prevalence among adults aged >=...     None             %
# 2  Binge drinking prevalence among adults aged >=...     None             %
# 3  Binge drinking prevalence among adults aged >=...     None             %
# 4  Binge drinking prevalence among adults aged >=...     None             %
#
#          ...        LocationID TopicID QuestionID DataValueTypeID  \
# 0        ...                59     ALC     ALC2_2         CRDPREV
# 1        ...                01     ALC     ALC2_2         CRDPREV
# 2        ...                02     ALC     ALC2_2         CRDPREV
# 3        ...                04     ALC     ALC2_2         CRDPREV
# 4        ...                05     ALC     ALC2_2         CRDPREV
#
#   StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# 0                   OVERALL               OVR                      None
# 1                   OVERALL               OVR                      None
# 2                   OVERALL               OVR                      None
# 3                   OVERALL               OVR                      None
# 4                   OVERALL               OVR                      None
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0              None                      None              None
# 1              None                      None              None
# 2              None                      None              None
# 3              None                      None              None
# 4              None                      None              None
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Level-Up
# ## Create a bar graph of states with the highest asthma rates for adults age 18+

# %%
df['YearStart'].unique_count()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-44-21a1ba0aec6f> in <module>()
# ----> 1 df['YearStart'].unique_count()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'unique_count'

# %%
df.columns
df['Topic'].value_counts()
df[df['Topic']=='Asthma']['Question'].value_counts()
df[(df['Topic']=='Asthma')&(df['Question']=='Current asthma prevalence among adults aged >= 18 years')][
    ['Question','LocationAbbr','DataValue']].sort_values(by = ['DataValue'])
# Out:
#                                                 Question LocationAbbr  \
# 10229  Current asthma prevalence among adults aged >=...           VI
# 9975   Current asthma prevalence among adults aged >=...           KY
# 9973   Current asthma prevalence among adults aged >=...           IA
# 9523   Current asthma prevalence among adults aged >=...           VI
# 9970   Current asthma prevalence among adults aged >=...           ID
# 9968   Current asthma prevalence among adults aged >=...           GA
# 9961   Current asthma prevalence among adults aged >=...           AR
# 9959   Current asthma prevalence among adults aged >=...           AK
# 9958   Current asthma prevalence among adults aged >=...           AL
# 9957   Current asthma prevalence among adults aged >=...           VI
# 9976   Current asthma prevalence among adults aged >=...           LA
# 9955   Current asthma prevalence among adults aged >=...           GU
# 9952   Current asthma prevalence among adults aged >=...           WV
# 9949   Current asthma prevalence among adults aged >=...           VT
# 9946   Current asthma prevalence among adults aged >=...           TN
# 9945   Current asthma prevalence among adults aged >=...           SD
# 9944   Current asthma prevalence among adults aged >=...           SC
# 9940   Current asthma prevalence among adults aged >=...           OK
# 9938   Current asthma prevalence among adults aged >=...           ND
# 9933   Current asthma prevalence among adults aged >=...           NH
# 9930   Current asthma prevalence among adults aged >=...           MT
# 9953   Current asthma prevalence among adults aged >=...           WI
# 9977   Current asthma prevalence among adults aged >=...           ME
# 9982   Current asthma prevalence among adults aged >=...           MS
# 9984   Current asthma prevalence among adults aged >=...           MT
# 10040  Current asthma prevalence among adults aged >=...           NV
# 10037  Current asthma prevalence among adults aged >=...           MO
# 10036  Current asthma prevalence among adults aged >=...           MS
# 10030  Current asthma prevalence among adults aged >=...           LA
# 10027  Current asthma prevalence among adults aged >=...           IA
# ...                                                  ...          ...
# 10189  Current asthma prevalence among adults aged >=...           IN
# 9969   Current asthma prevalence among adults aged >=...           HI
# 10197  Current asthma prevalence among adults aged >=...           MI
# 10180  Current asthma prevalence among adults aged >=...           CO
# 10116  Current asthma prevalence among adults aged >=...           WY
# 10156  Current asthma prevalence among adults aged >=...           OH
# 10142  Current asthma prevalence among adults aged >=...           MI
# 10203  Current asthma prevalence among adults aged >=...           NV
# 10210  Current asthma prevalence among adults aged >=...           OH
# 10175  Current asthma prevalence among adults aged >=...           AL
# 9942   Current asthma prevalence among adults aged >=...           PA
# 10031  Current asthma prevalence among adults aged >=...           ME
# 10134  Current asthma prevalence among adults aged >=...           IN
# 9915   Current asthma prevalence among adults aged >=...           HI
# 9996   Current asthma prevalence among adults aged >=...           PA
# 10125  Current asthma prevalence among adults aged >=...           CO
# 10085  Current asthma prevalence among adults aged >=...           ME
# 9993   Current asthma prevalence among adults aged >=...           OH
# 10202  Current asthma prevalence among adults aged >=...           NE
# 10143  Current asthma prevalence among adults aged >=...           MN
# 9939   Current asthma prevalence among adults aged >=...           OH
# 10198  Current asthma prevalence among adults aged >=...           MN
# 10192  Current asthma prevalence among adults aged >=...           KY
# 10188  Current asthma prevalence among adults aged >=...           IL
# 10137  Current asthma prevalence among adults aged >=...           KY
# 10155  Current asthma prevalence among adults aged >=...           ND
# 10209  Current asthma prevalence among adults aged >=...           ND
# 10194  Current asthma prevalence among adults aged >=...           ME
# 10133  Current asthma prevalence among adults aged >=...           IL
# 10139  Current asthma prevalence among adults aged >=...           ME
#
#        DataValue
# 10229        0.0
# 9975         0.0
# 9973         0.0
# 9523         0.0
# 9970         0.0
# 9968         0.0
# 9961         0.0
# 9959         0.0
# 9958         0.0
# 9957         0.0
# 9976         0.0
# 9955         0.0
# 9952         0.0
# 9949         0.0
# 9946         0.0
# 9945         0.0
# 9944         0.0
# 9940         0.0
# 9938         0.0
# 9933         0.0
# 9930         0.0
# 9953         0.0
# 9977         0.0
# 9982         0.0
# 9984         0.0
# 10040        0.0
# 10037        0.0
# 10036        0.0
# 10030        0.0
# 10027        0.0
# ...          ...
# 10189       17.2
# 9969        17.6
# 10197       17.7
# 10180       17.7
# 10116       17.8
# 10156       17.9
# 10142       18.0
# 10203       18.0
# 10210       18.3
# 10175       18.5
# 9942        18.5
# 10031       18.7
# 10134       18.7
# 9915        18.8
# 9996        19.1
# 10125       19.5
# 10085       19.6
# 9993        19.7
# 10202       20.1
# 10143       20.1
# 9939        21.1
# 10198       21.7
# 10192       22.6
# 10188       22.6
# 10137       23.1
# 10155       24.3
# 10209       24.9
# 10194       25.8
# 10133       27.5
# 10139       28.9
#
# [870 rows x 3 columns]

# %%
values = []
for n in range(0,len(df)):
    try:
        values.append(float(df['DataValue'][n]))
    except:
        values.append(0)

df['DataValue']= values
df['DataValue'][1]
# Out:
# 13.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.barplot(x="LocationAbbr", y="DataValue", 
            data=df[(df['Topic']=='Asthma')&
                    (df['Question']=='Current asthma prevalence among adults aged >= 18 years')].sort_values(
            by = ['DataValue']))
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Level-Up!
# ## Create a function (or class) that returns an outline of the schema structure like this:
# <img src="images/outline.jpg" width="350">
#
# Rules:
# * Your outline should follow the numbering outline above (I, A, 1, a, i).
# * Your outline should be properly indented! (Four spaces or one tab per indentation level.)
# * Your function goes to at least a depth of 5 (Level-up: create a parameter so that the user can specify this)
# * If an entry is a dictionary, list its keys as the subheadings
# * After listing a key name (where applicable) include a space, a dash and the data type of the entry
# * If an entry is a dict or list put in parentheses how many items are in the entry
# * lists will not have key names for their entries (they're just indexed)
# * For subheadings of a list, state their datatypes.
# * If a dictionary or list is more then 5 items long, only show the first 5 (we want to limit our previews); make an arbitrary order choice for dictionaries. (Level-up: Parallel to above; allow user to specify number of items to preview for large subheading collections.)

# %%
# Your code here; you will probably want to define subfunctions.
def print_obj_outline(json_obj):
    return outline

# %%
outline = print_obj_outline(data)

# %%
print(outline) #Your function should produce the following output for this json object (and work for all json files!)
# Out:
# I. root - <class 'dict'> (2 items)
#     A. meta <class 'dict'> (1 items)
#         1. view <class 'dict'> (40 items)
#             a. id <class 'str'>
#             b. name <class 'str'>
#             c. attribution <class 'str'>
#             d. attributionLink <class 'str'>
#             e. averageRating <class 'int'>
#     B. data <class 'list'> (60266 items)
#         1. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         2. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         3. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         4. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         5. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>

# %% [markdown]
# ## Summary
#
# Well done! In this lab you got some extended practice exploring the structure of JSON files and writing a recursive generalized function for outlining a JSON file's schema!
