# %% [markdown]
# # Exploring and Transforming JSON Schemas

# %% [markdown]
# # Introduction
#
# In this lesson, you'll formalize how to explore a JSON file whose structure and schema is unknown to you. This often happens in practice when you are handed a file or stumble upon one with little documentation.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Explore unknown JSON schemas
# * Access and manipulate data inside a JSON file
# * Convert JSON to alternative data formats

# %% [markdown]
# ## Loading the JSON file
#
# Load the data from the file disease_data.json.

# %%
import json
data = json.load(open('disease_data.json'))
type(data)
# Out:
# dict

# %% [markdown]
# ## Explore the first and second levels of the schema hierarchy

# %%
data.keys()
print(data['meta']['view']['columns'][9]['name'])
#dict with column names
#print(len(data['data'][1]))
#list of lists, with each list corresponding to one row
# Out:
# YearEnd

# %% [markdown]
# ## Convert to a DataFrame
#
# Create a DataFrame from the JSON file. Be sure to retrive the column names for the dataframe. (Search within the 'meta' key of the master dictionary.) The DataFrame should include all 42 columns.

# %%
import pandas as pd

# %%
columns = [x['name'] for x in data['meta']['view']['columns']]
df = pd.DataFrame()
for n in range(0,len(columns)):
    df['{}'.format(columns[n])] = [data['data'][i][n] for i in range(0,len(data['data']))]
df.head()
# Out:
#    sid                                    id  position  created_at  \
# 0    1  FF49C41F-CE8D-46C4-9164-653B1227CF6F         1  1527194521
# 1    2  F4468C3D-340A-4CD2-84A3-DF554DFF065E         2  1527194521
# 2    3  65609156-A343-4869-B03F-2BA62E96AC19         3  1527194521
# 3    4  0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3         4  1527194521
# 4    5  D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B         5  1527194521
#
#   created_meta  updated_at updated_meta  meta YearStart YearEnd  \
# 0       959778  1527194521       959778  None      2016    2016
# 1       959778  1527194521       959778  None      2016    2016
# 2       959778  1527194521       959778  None      2016    2016
# 3       959778  1527194521       959778  None      2016    2016
# 4       959778  1527194521       959778  None      2016    2016
#
#          ...        LocationID TopicID QuestionID DataValueTypeID  \
# 0        ...                59     ALC     ALC2_2         CRDPREV
# 1        ...                01     ALC     ALC2_2         CRDPREV
# 2        ...                02     ALC     ALC2_2         CRDPREV
# 3        ...                04     ALC     ALC2_2         CRDPREV
# 4        ...                05     ALC     ALC2_2         CRDPREV
#
#   StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# 0                   OVERALL               OVR                      None
# 1                   OVERALL               OVR                      None
# 2                   OVERALL               OVR                      None
# 3                   OVERALL               OVR                      None
# 4                   OVERALL               OVR                      None
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0              None                      None              None
# 1              None                      None              None
# 2              None                      None              None
# 3              None                      None              None
# 4              None                      None              None
#
# [5 rows x 42 columns]

# %%
df.drop('sid',axis=1,inplace=True)
df.drop('id',axis=1,inplace=True)
df.drop('created_at',axis=1,inplace=True)
df.drop('created_meta',axis=1,inplace=True)
df.drop('updated_at',axis=1,inplace=True)
df.drop('updated_meta',axis=1,inplace=True)
df.drop('meta',axis=1,inplace=True)
df.head()
# Out:
#    position YearStart YearEnd LocationAbbr   LocationDesc DataSource    Topic  \
# 0         1      2016    2016           US  United States      BRFSS  Alcohol
# 1         2      2016    2016           AL        Alabama      BRFSS  Alcohol
# 2         3      2016    2016           AK         Alaska      BRFSS  Alcohol
# 3         4      2016    2016           AZ        Arizona      BRFSS  Alcohol
# 4         5      2016    2016           AR       Arkansas      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...     None             %
# 1  Binge drinking prevalence among adults aged >=...     None             %
# 2  Binge drinking prevalence among adults aged >=...     None             %
# 3  Binge drinking prevalence among adults aged >=...     None             %
# 4  Binge drinking prevalence among adults aged >=...     None             %
#
#          ...        LocationID TopicID QuestionID DataValueTypeID  \
# 0        ...                59     ALC     ALC2_2         CRDPREV
# 1        ...                01     ALC     ALC2_2         CRDPREV
# 2        ...                02     ALC     ALC2_2         CRDPREV
# 3        ...                04     ALC     ALC2_2         CRDPREV
# 4        ...                05     ALC     ALC2_2         CRDPREV
#
#   StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# 0                   OVERALL               OVR                      None
# 1                   OVERALL               OVR                      None
# 2                   OVERALL               OVR                      None
# 3                   OVERALL               OVR                      None
# 4                   OVERALL               OVR                      None
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0              None                      None              None
# 1              None                      None              None
# 2              None                      None              None
# 3              None                      None              None
# 4              None                      None              None
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Level-Up
# ## Create a bar graph of states with the highest asthma rates for adults age 18+

# %%
df.columns
# Out:
# Index(['position', 'YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc',
#        'DataSource', 'Topic', 'Question', 'Response', 'DataValueUnit',
#        'DataValueType', 'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
df.columns
df['Topic'].value_counts()
df[df['Topic']=='Asthma']['Question'].value_counts()
df[(df['Topic']=='Asthma')&(df['Question']=='Current asthma prevalence among adults aged >= 18 years')
  ].sort_values(by = ['DataValue'])
# Out:
#        position YearStart YearEnd LocationAbbr    LocationDesc DataSource  \
# 10229     10226      2016    2016           VI  Virgin Islands      BRFSS
# 9975       9972      2016    2016           KY        Kentucky      BRFSS
# 9973       9970      2016    2016           IA            Iowa      BRFSS
# 9523       9520      2016    2016           VI  Virgin Islands      BRFSS
# 9970       9967      2016    2016           ID           Idaho      BRFSS
# 9968       9965      2016    2016           GA         Georgia      BRFSS
# 9961       9958      2016    2016           AR        Arkansas      BRFSS
# 9959       9956      2016    2016           AK          Alaska      BRFSS
# 9958       9955      2016    2016           AL         Alabama      BRFSS
# 9957       9954      2016    2016           VI  Virgin Islands      BRFSS
# 9976       9973      2016    2016           LA       Louisiana      BRFSS
# 9955       9952      2016    2016           GU            Guam      BRFSS
# 9952       9949      2016    2016           WV   West Virginia      BRFSS
# 9949       9946      2016    2016           VT         Vermont      BRFSS
# 9946       9943      2016    2016           TN       Tennessee      BRFSS
# 9945       9942      2016    2016           SD    South Dakota      BRFSS
# 9944       9941      2016    2016           SC  South Carolina      BRFSS
# 9940       9937      2016    2016           OK        Oklahoma      BRFSS
# 9938       9935      2016    2016           ND    North Dakota      BRFSS
# 9933       9930      2016    2016           NH   New Hampshire      BRFSS
# 9930       9927      2016    2016           MT         Montana      BRFSS
# 9953       9950      2016    2016           WI       Wisconsin      BRFSS
# 9977       9974      2016    2016           ME           Maine      BRFSS
# 9982       9979      2016    2016           MS     Mississippi      BRFSS
# 9984       9981      2016    2016           MT         Montana      BRFSS
# 10040     10037      2016    2016           NV          Nevada      BRFSS
# 10037     10034      2016    2016           MO        Missouri      BRFSS
# 10036     10033      2016    2016           MS     Mississippi      BRFSS
# 10030     10027      2016    2016           LA       Louisiana      BRFSS
# 10027     10024      2016    2016           IA            Iowa      BRFSS
# ...         ...       ...     ...          ...             ...        ...
# 10189     10186      2016    2016           IN         Indiana      BRFSS
# 9969       9966      2016    2016           HI          Hawaii      BRFSS
# 10197     10194      2016    2016           MI        Michigan      BRFSS
# 10180     10177      2016    2016           CO        Colorado      BRFSS
# 10116     10113      2016    2016           WY         Wyoming      BRFSS
# 10156     10153      2016    2016           OH            Ohio      BRFSS
# 10142     10139      2016    2016           MI        Michigan      BRFSS
# 10203     10200      2016    2016           NV          Nevada      BRFSS
# 10210     10207      2016    2016           OH            Ohio      BRFSS
# 10175     10172      2016    2016           AL         Alabama      BRFSS
# 9942       9939      2016    2016           PA    Pennsylvania      BRFSS
# 10031     10028      2016    2016           ME           Maine      BRFSS
# 10134     10131      2016    2016           IN         Indiana      BRFSS
# 9915       9912      2016    2016           HI          Hawaii      BRFSS
# 9996       9993      2016    2016           PA    Pennsylvania      BRFSS
# 10125     10122      2016    2016           CO        Colorado      BRFSS
# 10085     10082      2016    2016           ME           Maine      BRFSS
# 9993       9990      2016    2016           OH            Ohio      BRFSS
# 10202     10199      2016    2016           NE        Nebraska      BRFSS
# 10143     10140      2016    2016           MN       Minnesota      BRFSS
# 9939       9936      2016    2016           OH            Ohio      BRFSS
# 10198     10195      2016    2016           MN       Minnesota      BRFSS
# 10192     10189      2016    2016           KY        Kentucky      BRFSS
# 10188     10185      2016    2016           IL        Illinois      BRFSS
# 10137     10134      2016    2016           KY        Kentucky      BRFSS
# 10155     10152      2016    2016           ND    North Dakota      BRFSS
# 10209     10206      2016    2016           ND    North Dakota      BRFSS
# 10194     10191      2016    2016           ME           Maine      BRFSS
# 10133     10130      2016    2016           IL        Illinois      BRFSS
# 10139     10136      2016    2016           ME           Maine      BRFSS
#
#         Topic                                           Question Response  \
# 10229  Asthma  Current asthma prevalence among adults aged >=...     None
# 9975   Asthma  Current asthma prevalence among adults aged >=...     None
# 9973   Asthma  Current asthma prevalence among adults aged >=...     None
# 9523   Asthma  Current asthma prevalence among adults aged >=...     None
# 9970   Asthma  Current asthma prevalence among adults aged >=...     None
# 9968   Asthma  Current asthma prevalence among adults aged >=...     None
# 9961   Asthma  Current asthma prevalence among adults aged >=...     None
# 9959   Asthma  Current asthma prevalence among adults aged >=...     None
# 9958   Asthma  Current asthma prevalence among adults aged >=...     None
# 9957   Asthma  Current asthma prevalence among adults aged >=...     None
# 9976   Asthma  Current asthma prevalence among adults aged >=...     None
# 9955   Asthma  Current asthma prevalence among adults aged >=...     None
# 9952   Asthma  Current asthma prevalence among adults aged >=...     None
# 9949   Asthma  Current asthma prevalence among adults aged >=...     None
# 9946   Asthma  Current asthma prevalence among adults aged >=...     None
# 9945   Asthma  Current asthma prevalence among adults aged >=...     None
# 9944   Asthma  Current asthma prevalence among adults aged >=...     None
# 9940   Asthma  Current asthma prevalence among adults aged >=...     None
# 9938   Asthma  Current asthma prevalence among adults aged >=...     None
# 9933   Asthma  Current asthma prevalence among adults aged >=...     None
# 9930   Asthma  Current asthma prevalence among adults aged >=...     None
# 9953   Asthma  Current asthma prevalence among adults aged >=...     None
# 9977   Asthma  Current asthma prevalence among adults aged >=...     None
# 9982   Asthma  Current asthma prevalence among adults aged >=...     None
# 9984   Asthma  Current asthma prevalence among adults aged >=...     None
# 10040  Asthma  Current asthma prevalence among adults aged >=...     None
# 10037  Asthma  Current asthma prevalence among adults aged >=...     None
# 10036  Asthma  Current asthma prevalence among adults aged >=...     None
# 10030  Asthma  Current asthma prevalence among adults aged >=...     None
# 10027  Asthma  Current asthma prevalence among adults aged >=...     None
# ...       ...                                                ...      ...
# 10189  Asthma  Current asthma prevalence among adults aged >=...     None
# 9969   Asthma  Current asthma prevalence among adults aged >=...     None
# 10197  Asthma  Current asthma prevalence among adults aged >=...     None
# 10180  Asthma  Current asthma prevalence among adults aged >=...     None
# 10116  Asthma  Current asthma prevalence among adults aged >=...     None
# 10156  Asthma  Current asthma prevalence among adults aged >=...     None
# 10142  Asthma  Current asthma prevalence among adults aged >=...     None
# 10203  Asthma  Current asthma prevalence among adults aged >=...     None
# 10210  Asthma  Current asthma prevalence among adults aged >=...     None
# 10175  Asthma  Current asthma prevalence among adults aged >=...     None
# 9942   Asthma  Current asthma prevalence among adults aged >=...     None
# 10031  Asthma  Current asthma prevalence among adults aged >=...     None
# 10134  Asthma  Current asthma prevalence among adults aged >=...     None
# 9915   Asthma  Current asthma prevalence among adults aged >=...     None
# 9996   Asthma  Current asthma prevalence among adults aged >=...     None
# 10125  Asthma  Current asthma prevalence among adults aged >=...     None
# 10085  Asthma  Current asthma prevalence among adults aged >=...     None
# 9993   Asthma  Current asthma prevalence among adults aged >=...     None
# 10202  Asthma  Current asthma prevalence among adults aged >=...     None
# 10143  Asthma  Current asthma prevalence among adults aged >=...     None
# 9939   Asthma  Current asthma prevalence among adults aged >=...     None
# 10198  Asthma  Current asthma prevalence among adults aged >=...     None
# 10192  Asthma  Current asthma prevalence among adults aged >=...     None
# 10188  Asthma  Current asthma prevalence among adults aged >=...     None
# 10137  Asthma  Current asthma prevalence among adults aged >=...     None
# 10155  Asthma  Current asthma prevalence among adults aged >=...     None
# 10209  Asthma  Current asthma prevalence among adults aged >=...     None
# 10194  Asthma  Current asthma prevalence among adults aged >=...     None
# 10133  Asthma  Current asthma prevalence among adults aged >=...     None
# 10139  Asthma  Current asthma prevalence among adults aged >=...     None
#
#       DataValueUnit        ...        LocationID  TopicID QuestionID  \
# 10229             %        ...                78      AST     AST1_1
# 9975              %        ...                21      AST     AST1_1
# 9973              %        ...                19      AST     AST1_1
# 9523              %        ...                78      AST     AST1_1
# 9970              %        ...                16      AST     AST1_1
# 9968              %        ...                13      AST     AST1_1
# 9961              %        ...                05      AST     AST1_1
# 9959              %        ...                02      AST     AST1_1
# 9958              %        ...                01      AST     AST1_1
# 9957              %        ...                78      AST     AST1_1
# 9976              %        ...                22      AST     AST1_1
# 9955              %        ...                66      AST     AST1_1
# 9952              %        ...                54      AST     AST1_1
# 9949              %        ...                50      AST     AST1_1
# 9946              %        ...                47      AST     AST1_1
# 9945              %        ...                46      AST     AST1_1
# 9944              %        ...                45      AST     AST1_1
# 9940              %        ...                40      AST     AST1_1
# 9938              %        ...                38      AST     AST1_1
# 9933              %        ...                33      AST     AST1_1
# 9930              %        ...                30      AST     AST1_1
# 9953              %        ...                55      AST     AST1_1
# 9977              %        ...                23      AST     AST1_1
# 9982              %        ...                28      AST     AST1_1
# 9984              %        ...                30      AST     AST1_1
# 10040             %        ...                32      AST     AST1_1
# 10037             %        ...                29      AST     AST1_1
# 10036             %        ...                28      AST     AST1_1
# 10030             %        ...                22      AST     AST1_1
# 10027             %        ...                19      AST     AST1_1
# ...             ...        ...               ...      ...        ...
# 10189             %        ...                18      AST     AST1_1
# 9969              %        ...                15      AST     AST1_1
# 10197             %        ...                26      AST     AST1_1
# 10180             %        ...                08      AST     AST1_1
# 10116             %        ...                56      AST     AST1_1
# 10156             %        ...                39      AST     AST1_1
# 10142             %        ...                26      AST     AST1_1
# 10203             %        ...                32      AST     AST1_1
# 10210             %        ...                39      AST     AST1_1
# 10175             %        ...                01      AST     AST1_1
# 9942              %        ...                42      AST     AST1_1
# 10031             %        ...                23      AST     AST1_1
# 10134             %        ...                18      AST     AST1_1
# 9915              %        ...                15      AST     AST1_1
# 9996              %        ...                42      AST     AST1_1
# 10125             %        ...                08      AST     AST1_1
# 10085             %        ...                23      AST     AST1_1
# 9993              %        ...                39      AST     AST1_1
# 10202             %        ...                31      AST     AST1_1
# 10143             %        ...                27      AST     AST1_1
# 9939              %        ...                39      AST     AST1_1
# 10198             %        ...                27      AST     AST1_1
# 10192             %        ...                21      AST     AST1_1
# 10188             %        ...                17      AST     AST1_1
# 10137             %        ...                21      AST     AST1_1
# 10155             %        ...                38      AST     AST1_1
# 10209             %        ...                38      AST     AST1_1
# 10194             %        ...                23      AST     AST1_1
# 10133             %        ...                17      AST     AST1_1
# 10139             %        ...                23      AST     AST1_1
#
#       DataValueTypeID StratificationCategoryID1 StratificationID1  \
# 10229      AGEADJPREV                      RACE               MRC
# 9975       AGEADJPREV                      RACE               HIS
# 9973       AGEADJPREV                      RACE               HIS
# 9523          CRDPREV                    GENDER              GENM
# 9970       AGEADJPREV                      RACE               HIS
# 9968       AGEADJPREV                      RACE               HIS
# 9961       AGEADJPREV                      RACE               HIS
# 9959       AGEADJPREV                      RACE               HIS
# 9958       AGEADJPREV                      RACE               HIS
# 9957          CRDPREV                      RACE               HIS
# 9976       AGEADJPREV                      RACE               HIS
# 9955          CRDPREV                      RACE               HIS
# 9952          CRDPREV                      RACE               HIS
# 9949          CRDPREV                      RACE               HIS
# 9946          CRDPREV                      RACE               HIS
# 9945          CRDPREV                      RACE               HIS
# 9944          CRDPREV                      RACE               HIS
# 9940          CRDPREV                      RACE               HIS
# 9938          CRDPREV                      RACE               HIS
# 9933          CRDPREV                      RACE               HIS
# 9930          CRDPREV                      RACE               HIS
# 9953          CRDPREV                      RACE               HIS
# 9977       AGEADJPREV                      RACE               HIS
# 9982       AGEADJPREV                      RACE               HIS
# 9984       AGEADJPREV                      RACE               HIS
# 10040         CRDPREV                      RACE               OTH
# 10037         CRDPREV                      RACE               OTH
# 10036         CRDPREV                      RACE               OTH
# 10030         CRDPREV                      RACE               OTH
# 10027         CRDPREV                      RACE               OTH
# ...               ...                       ...               ...
# 10189      AGEADJPREV                      RACE               MRC
# 9969       AGEADJPREV                      RACE               HIS
# 10197      AGEADJPREV                      RACE               MRC
# 10180      AGEADJPREV                      RACE               MRC
# 10116      AGEADJPREV                      RACE               OTH
# 10156         CRDPREV                      RACE               MRC
# 10142         CRDPREV                      RACE               MRC
# 10203      AGEADJPREV                      RACE               MRC
# 10210      AGEADJPREV                      RACE               MRC
# 10175      AGEADJPREV                      RACE               MRC
# 9942          CRDPREV                      RACE               HIS
# 10031         CRDPREV                      RACE               OTH
# 10134         CRDPREV                      RACE               MRC
# 9915          CRDPREV                      RACE               HIS
# 9996       AGEADJPREV                      RACE               HIS
# 10125         CRDPREV                      RACE               MRC
# 10085      AGEADJPREV                      RACE               OTH
# 9993       AGEADJPREV                      RACE               HIS
# 10202      AGEADJPREV                      RACE               MRC
# 10143         CRDPREV                      RACE               MRC
# 9939          CRDPREV                      RACE               HIS
# 10198      AGEADJPREV                      RACE               MRC
# 10192      AGEADJPREV                      RACE               MRC
# 10188      AGEADJPREV                      RACE               MRC
# 10137         CRDPREV                      RACE               MRC
# 10155         CRDPREV                      RACE               MRC
# 10209      AGEADJPREV                      RACE               MRC
# 10194      AGEADJPREV                      RACE               MRC
# 10133         CRDPREV                      RACE               MRC
# 10139         CRDPREV                      RACE               MRC
#
#       StratificationCategoryID2 StratificationID2 StratificationCategoryID3  \
# 10229                      None              None                      None
# 9975                       None              None                      None
# 9973                       None              None                      None
# 9523                       None              None                      None
# 9970                       None              None                      None
# 9968                       None              None                      None
# 9961                       None              None                      None
# 9959                       None              None                      None
# 9958                       None              None                      None
# 9957                       None              None                      None
# 9976                       None              None                      None
# 9955                       None              None                      None
# 9952                       None              None                      None
# 9949                       None              None                      None
# 9946                       None              None                      None
# 9945                       None              None                      None
# 9944                       None              None                      None
# 9940                       None              None                      None
# 9938                       None              None                      None
# 9933                       None              None                      None
# 9930                       None              None                      None
# 9953                       None              None                      None
# 9977                       None              None                      None
# 9982                       None              None                      None
# 9984                       None              None                      None
# 10040                      None              None                      None
# 10037                      None              None                      None
# 10036                      None              None                      None
# 10030                      None              None                      None
# 10027                      None              None                      None
# ...                         ...               ...                       ...
# 10189                      None              None                      None
# 9969                       None              None                      None
# 10197                      None              None                      None
# 10180                      None              None                      None
# 10116                      None              None                      None
# 10156                      None              None                      None
# 10142                      None              None                      None
# 10203                      None              None                      None
# 10210                      None              None                      None
# 10175                      None              None                      None
# 9942                       None              None                      None
# 10031                      None              None                      None
# 10134                      None              None                      None
# 9915                       None              None                      None
# 9996                       None              None                      None
# 10125                      None              None                      None
# 10085                      None              None                      None
# 9993                       None              None                      None
# 10202                      None              None                      None
# 10143                      None              None                      None
# 9939                       None              None                      None
# 10198                      None              None                      None
# 10192                      None              None                      None
# 10188                      None              None                      None
# 10137                      None              None                      None
# 10155                      None              None                      None
# 10209                      None              None                      None
# 10194                      None              None                      None
# 10133                      None              None                      None
# 10139                      None              None                      None
#
#       StratificationID3
# 10229              None
# 9975               None
# 9973               None
# 9523               None
# 9970               None
# 9968               None
# 9961               None
# 9959               None
# 9958               None
# 9957               None
# 9976               None
# 9955               None
# 9952               None
# 9949               None
# 9946               None
# 9945               None
# 9944               None
# 9940               None
# 9938               None
# 9933               None
# 9930               None
# 9953               None
# 9977               None
# 9982               None
# 9984               None
# 10040              None
# 10037              None
# 10036              None
# 10030              None
# 10027              None
# ...                 ...
# 10189              None
# 9969               None
# 10197              None
# 10180              None
# 10116              None
# 10156              None
# 10142              None
# 10203              None
# 10210              None
# 10175              None
# 9942               None
# 10031              None
# 10134              None
# 9915               None
# 9996               None
# 10125              None
# 10085              None
# 9993               None
# 10202              None
# 10143              None
# 9939               None
# 10198              None
# 10192              None
# 10188              None
# 10137              None
# 10155              None
# 10209              None
# 10194              None
# 10133              None
# 10139              None
#
# [870 rows x 35 columns]

# %%
values = []
for n in range(0,len(df)):
    try:
        values.append(float(df['DataValue'][n]))
    except:
        values.append(0)

df['DataValue']= values
df['DataValue'][1]
# Out:
# 13.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.barplot(x="LocationAbbr", y="DataValue", 
            data=df[(df['Topic']=='Asthma')&
                    (df['Question']=='Current asthma prevalence among adults aged >= 18 years')][[
                'Question','LocationAbbr','DataValue']].sort_values(by = ['DataValue']))
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Level-Up!
# ## Create a function (or class) that returns an outline of the schema structure like this:
# <img src="images/outline.jpg" width="350">
#
# Rules:
# * Your outline should follow the numbering outline above (I, A, 1, a, i).
# * Your outline should be properly indented! (Four spaces or one tab per indentation level.)
# * Your function goes to at least a depth of 5 (Level-up: create a parameter so that the user can specify this)
# * If an entry is a dictionary, list its keys as the subheadings
# * After listing a key name (where applicable) include a space, a dash and the data type of the entry
# * If an entry is a dict or list put in parentheses how many items are in the entry
# * lists will not have key names for their entries (they're just indexed)
# * For subheadings of a list, state their datatypes.
# * If a dictionary or list is more then 5 items long, only show the first 5 (we want to limit our previews); make an arbitrary order choice for dictionaries. (Level-up: Parallel to above; allow user to specify number of items to preview for large subheading collections.)

# %%
# Your code here; you will probably want to define subfunctions.
def print_obj_outline(json_obj):
    return outline

# %%
outline = print_obj_outline(data)

# %%
print(outline) #Your function should produce the following output for this json object (and work for all json files!)
# Out:
# I. root - <class 'dict'> (2 items)
#     A. meta <class 'dict'> (1 items)
#         1. view <class 'dict'> (40 items)
#             a. id <class 'str'>
#             b. name <class 'str'>
#             c. attribution <class 'str'>
#             d. attributionLink <class 'str'>
#             e. averageRating <class 'int'>
#     B. data <class 'list'> (60266 items)
#         1. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         2. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         3. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         4. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         5. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>

# %% [markdown]
# ## Summary
#
# Well done! In this lab you got some extended practice exploring the structure of JSON files and writing a recursive generalized function for outlining a JSON file's schema!
