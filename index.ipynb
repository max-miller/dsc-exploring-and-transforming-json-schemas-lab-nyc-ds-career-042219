# %% [markdown]
# # Exploring and Transforming JSON Schemas

# %% [markdown]
# # Introduction
#
# In this lesson, you'll formalize how to explore a JSON file whose structure and schema is unknown to you. This often happens in practice when you are handed a file or stumble upon one with little documentation.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Explore unknown JSON schemas
# * Access and manipulate data inside a JSON file
# * Convert JSON to alternative data formats

# %% [markdown]
# ## Loading the JSON file
#
# Load the data from the file disease_data.json.

# %%
import json
data = json.load(open('disease_data.json'))
type(data)
# Out:
# dict

# %% [markdown]
# ## Explore the first and second levels of the schema hierarchy

# %%
data.keys()
print(data['meta']['view']['columns'][9]['name'])
#dict with column names
#print(len(data['data'][1]))
#list of lists, with each list corresponding to one row
# Out:
# YearEnd

# %% [markdown]
# ## Convert to a DataFrame
#
# Create a DataFrame from the JSON file. Be sure to retrive the column names for the dataframe. (Search within the 'meta' key of the master dictionary.) The DataFrame should include all 42 columns.

# %%
import pandas as pd

# %%
columns = [x['name'] for x in data['meta']['view']['columns']]
df = pd.DataFrame()
for n in range(0,len(columns)):
    df['{}'.format(columns[n])] = [data['data'][i][n] for i in range(0,len(data['data']))]
df.head()
# Out:
#    sid                                    id  position  created_at  \
# 0    1  FF49C41F-CE8D-46C4-9164-653B1227CF6F         1  1527194521
# 1    2  F4468C3D-340A-4CD2-84A3-DF554DFF065E         2  1527194521
# 2    3  65609156-A343-4869-B03F-2BA62E96AC19         3  1527194521
# 3    4  0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3         4  1527194521
# 4    5  D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B         5  1527194521
#
#   created_meta  updated_at updated_meta  meta YearStart YearEnd  \
# 0       959778  1527194521       959778  None      2016    2016
# 1       959778  1527194521       959778  None      2016    2016
# 2       959778  1527194521       959778  None      2016    2016
# 3       959778  1527194521       959778  None      2016    2016
# 4       959778  1527194521       959778  None      2016    2016
#
#          ...        LocationID TopicID QuestionID DataValueTypeID  \
# 0        ...                59     ALC     ALC2_2         CRDPREV
# 1        ...                01     ALC     ALC2_2         CRDPREV
# 2        ...                02     ALC     ALC2_2         CRDPREV
# 3        ...                04     ALC     ALC2_2         CRDPREV
# 4        ...                05     ALC     ALC2_2         CRDPREV
#
#   StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# 0                   OVERALL               OVR                      None
# 1                   OVERALL               OVR                      None
# 2                   OVERALL               OVR                      None
# 3                   OVERALL               OVR                      None
# 4                   OVERALL               OVR                      None
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0              None                      None              None
# 1              None                      None              None
# 2              None                      None              None
# 3              None                      None              None
# 4              None                      None              None
#
# [5 rows x 42 columns]

# %%
df.drop('sid',axis=1,inplace=True)
df.drop('id',axis=1,inplace=True)
df.drop('created_at',axis=1,inplace=True)
df.drop('created_meta',axis=1,inplace=True)
df.drop('updated_at',axis=1,inplace=True)
df.drop('updated_meta',axis=1,inplace=True)
df.drop('meta',axis=1,inplace=True)
df.head()
# Out:
#    position YearStart YearEnd LocationAbbr   LocationDesc DataSource    Topic  \
# 0         1      2016    2016           US  United States      BRFSS  Alcohol
# 1         2      2016    2016           AL        Alabama      BRFSS  Alcohol
# 2         3      2016    2016           AK         Alaska      BRFSS  Alcohol
# 3         4      2016    2016           AZ        Arizona      BRFSS  Alcohol
# 4         5      2016    2016           AR       Arkansas      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...     None             %
# 1  Binge drinking prevalence among adults aged >=...     None             %
# 2  Binge drinking prevalence among adults aged >=...     None             %
# 3  Binge drinking prevalence among adults aged >=...     None             %
# 4  Binge drinking prevalence among adults aged >=...     None             %
#
#          ...        LocationID TopicID QuestionID DataValueTypeID  \
# 0        ...                59     ALC     ALC2_2         CRDPREV
# 1        ...                01     ALC     ALC2_2         CRDPREV
# 2        ...                02     ALC     ALC2_2         CRDPREV
# 3        ...                04     ALC     ALC2_2         CRDPREV
# 4        ...                05     ALC     ALC2_2         CRDPREV
#
#   StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# 0                   OVERALL               OVR                      None
# 1                   OVERALL               OVR                      None
# 2                   OVERALL               OVR                      None
# 3                   OVERALL               OVR                      None
# 4                   OVERALL               OVR                      None
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0              None                      None              None
# 1              None                      None              None
# 2              None                      None              None
# 3              None                      None              None
# 4              None                      None              None
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Level-Up
# ## Create a bar graph of states with the highest asthma rates for adults age 18+

# %%
df.columns
# Out:
# Index(['position', 'YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc',
#        'DataSource', 'Topic', 'Question', 'Response', 'DataValueUnit',
#        'DataValueType', 'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
df.columns
df['Topic'].value_counts()
df[df['Topic']=='Asthma']['Question'].value_counts()
df[(df['Topic']=='Asthma')&(df['Question']=='Current asthma prevalence among adults aged >= 18 years')
  &(df['StratificationCategoryID1']=='OVERALL')].sort_values(by = ['DataValue'])
# Out:
#       position YearStart YearEnd LocationAbbr    LocationDesc DataSource  \
# 9422      9420      2016    2016           GU            Guam      BRFSS
# 9477      9475      2016    2016           GU            Guam      BRFSS
# 9467      9465      2016    2016           SD    South Dakota      BRFSS
# 9412      9410      2016    2016           SD    South Dakota      BRFSS
# 9424      9422      2016    2016           VI  Virgin Islands      BRFSS
# 9479      9477      2016    2016           VI  Virgin Islands      BRFSS
# 9380      9378      2016    2016           FL         Florida      BRFSS
# 9435      9433      2016    2016           FL         Florida      BRFSS
# 9469      9467      2016    2016           TX           Texas      BRFSS
# 9414      9412      2016    2016           TX           Texas      BRFSS
# 9394      9392      2016    2016           MN       Minnesota      BRFSS
# 9449      9447      2016    2016           MN       Minnesota      BRFSS
# 9430      9428      2016    2016           CA      California      BRFSS
# 9375      9373      2016    2016           CA      California      BRFSS
# 9441      9439      2016    2016           IA            Iowa      BRFSS
# 9386      9384      2016    2016           IA            Iowa      BRFSS
# 9450      9448      2016    2016           MS     Mississippi      BRFSS
# 9399      9397      2016    2016           NV          Nevada      BRFSS
# 9454      9452      2016    2016           NV          Nevada      BRFSS
# 9404      9402      2016    2016           NC  North Carolina      BRFSS
# 9395      9393      2016    2016           MS     Mississippi      BRFSS
# 9459      9457      2016    2016           NC  North Carolina      BRFSS
# 9453      9451      2016    2016           NE        Nebraska      BRFSS
# 9470      9468      2016    2016           UT            Utah      BRFSS
# 9415      9413      2016    2016           UT            Utah      BRFSS
# 9401      9399      2016    2016           NJ      New Jersey      BRFSS
# 9456      9454      2016    2016           NJ      New Jersey      BRFSS
# 9389      9387      2016    2016           LA       Louisiana      BRFSS
# 9398      9396      2016    2016           NE        Nebraska      BRFSS
# 9444      9442      2016    2016           LA       Louisiana      BRFSS
# ...        ...       ...     ...          ...             ...        ...
# 9385      9383      2016    2016           IN         Indiana      BRFSS
# 9447      9445      2016    2016           MA   Massachusetts      BRFSS
# 9392      9390      2016    2016           MA   Massachusetts      BRFSS
# 9471      9469      2016    2016           VT         Vermont      BRFSS
# 9465      9463      2016    2016           RI    Rhode Island      BRFSS
# 9377      9375      2016    2016           CT     Connecticut      BRFSS
# 9408      9406      2016    2016           OR          Oregon      BRFSS
# 9432      9430      2016    2016           CT     Connecticut      BRFSS
# 9463      9461      2016    2016           OR          Oregon      BRFSS
# 9409      9407      2016    2016           PA    Pennsylvania      BRFSS
# 9464      9462      2016    2016           PA    Pennsylvania      BRFSS
# 9382      9380      2016    2016           HI          Hawaii      BRFSS
# 9423      9421      2016    2016           PR     Puerto Rico      BRFSS
# 9437      9435      2016    2016           HI          Hawaii      BRFSS
# 9410      9408      2016    2016           RI    Rhode Island      BRFSS
# 9478      9476      2016    2016           PR     Puerto Rico      BRFSS
# 9393      9391      2016    2016           MI        Michigan      BRFSS
# 9413      9411      2016    2016           TN       Tennessee      BRFSS
# 9468      9466      2016    2016           TN       Tennessee      BRFSS
# 9448      9446      2016    2016           MI        Michigan      BRFSS
# 9400      9398      2016    2016           NH   New Hampshire      BRFSS
# 9443      9441      2016    2016           KY        Kentucky      BRFSS
# 9388      9386      2016    2016           KY        Kentucky      BRFSS
# 9402      9400      2016    2016           NM      New Mexico      BRFSS
# 9474      9472      2016    2016           WV   West Virginia      BRFSS
# 9419      9417      2016    2016           WV   West Virginia      BRFSS
# 9457      9455      2016    2016           NM      New Mexico      BRFSS
# 9455      9453      2016    2016           NH   New Hampshire      BRFSS
# 9390      9388      2016    2016           ME           Maine      BRFSS
# 9445      9443      2016    2016           ME           Maine      BRFSS
#
#        Topic                                           Question Response  \
# 9422  Asthma  Current asthma prevalence among adults aged >=...     None
# 9477  Asthma  Current asthma prevalence among adults aged >=...     None
# 9467  Asthma  Current asthma prevalence among adults aged >=...     None
# 9412  Asthma  Current asthma prevalence among adults aged >=...     None
# 9424  Asthma  Current asthma prevalence among adults aged >=...     None
# 9479  Asthma  Current asthma prevalence among adults aged >=...     None
# 9380  Asthma  Current asthma prevalence among adults aged >=...     None
# 9435  Asthma  Current asthma prevalence among adults aged >=...     None
# 9469  Asthma  Current asthma prevalence among adults aged >=...     None
# 9414  Asthma  Current asthma prevalence among adults aged >=...     None
# 9394  Asthma  Current asthma prevalence among adults aged >=...     None
# 9449  Asthma  Current asthma prevalence among adults aged >=...     None
# 9430  Asthma  Current asthma prevalence among adults aged >=...     None
# 9375  Asthma  Current asthma prevalence among adults aged >=...     None
# 9441  Asthma  Current asthma prevalence among adults aged >=...     None
# 9386  Asthma  Current asthma prevalence among adults aged >=...     None
# 9450  Asthma  Current asthma prevalence among adults aged >=...     None
# 9399  Asthma  Current asthma prevalence among adults aged >=...     None
# 9454  Asthma  Current asthma prevalence among adults aged >=...     None
# 9404  Asthma  Current asthma prevalence among adults aged >=...     None
# 9395  Asthma  Current asthma prevalence among adults aged >=...     None
# 9459  Asthma  Current asthma prevalence among adults aged >=...     None
# 9453  Asthma  Current asthma prevalence among adults aged >=...     None
# 9470  Asthma  Current asthma prevalence among adults aged >=...     None
# 9415  Asthma  Current asthma prevalence among adults aged >=...     None
# 9401  Asthma  Current asthma prevalence among adults aged >=...     None
# 9456  Asthma  Current asthma prevalence among adults aged >=...     None
# 9389  Asthma  Current asthma prevalence among adults aged >=...     None
# 9398  Asthma  Current asthma prevalence among adults aged >=...     None
# 9444  Asthma  Current asthma prevalence among adults aged >=...     None
# ...      ...                                                ...      ...
# 9385  Asthma  Current asthma prevalence among adults aged >=...     None
# 9447  Asthma  Current asthma prevalence among adults aged >=...     None
# 9392  Asthma  Current asthma prevalence among adults aged >=...     None
# 9471  Asthma  Current asthma prevalence among adults aged >=...     None
# 9465  Asthma  Current asthma prevalence among adults aged >=...     None
# 9377  Asthma  Current asthma prevalence among adults aged >=...     None
# 9408  Asthma  Current asthma prevalence among adults aged >=...     None
# 9432  Asthma  Current asthma prevalence among adults aged >=...     None
# 9463  Asthma  Current asthma prevalence among adults aged >=...     None
# 9409  Asthma  Current asthma prevalence among adults aged >=...     None
# 9464  Asthma  Current asthma prevalence among adults aged >=...     None
# 9382  Asthma  Current asthma prevalence among adults aged >=...     None
# 9423  Asthma  Current asthma prevalence among adults aged >=...     None
# 9437  Asthma  Current asthma prevalence among adults aged >=...     None
# 9410  Asthma  Current asthma prevalence among adults aged >=...     None
# 9478  Asthma  Current asthma prevalence among adults aged >=...     None
# 9393  Asthma  Current asthma prevalence among adults aged >=...     None
# 9413  Asthma  Current asthma prevalence among adults aged >=...     None
# 9468  Asthma  Current asthma prevalence among adults aged >=...     None
# 9448  Asthma  Current asthma prevalence among adults aged >=...     None
# 9400  Asthma  Current asthma prevalence among adults aged >=...     None
# 9443  Asthma  Current asthma prevalence among adults aged >=...     None
# 9388  Asthma  Current asthma prevalence among adults aged >=...     None
# 9402  Asthma  Current asthma prevalence among adults aged >=...     None
# 9474  Asthma  Current asthma prevalence among adults aged >=...     None
# 9419  Asthma  Current asthma prevalence among adults aged >=...     None
# 9457  Asthma  Current asthma prevalence among adults aged >=...     None
# 9455  Asthma  Current asthma prevalence among adults aged >=...     None
# 9390  Asthma  Current asthma prevalence among adults aged >=...     None
# 9445  Asthma  Current asthma prevalence among adults aged >=...     None
#
#      DataValueUnit        ...        LocationID  TopicID QuestionID  \
# 9422             %        ...                66      AST     AST1_1
# 9477             %        ...                66      AST     AST1_1
# 9467             %        ...                46      AST     AST1_1
# 9412             %        ...                46      AST     AST1_1
# 9424             %        ...                78      AST     AST1_1
# 9479             %        ...                78      AST     AST1_1
# 9380             %        ...                12      AST     AST1_1
# 9435             %        ...                12      AST     AST1_1
# 9469             %        ...                48      AST     AST1_1
# 9414             %        ...                48      AST     AST1_1
# 9394             %        ...                27      AST     AST1_1
# 9449             %        ...                27      AST     AST1_1
# 9430             %        ...                06      AST     AST1_1
# 9375             %        ...                06      AST     AST1_1
# 9441             %        ...                19      AST     AST1_1
# 9386             %        ...                19      AST     AST1_1
# 9450             %        ...                28      AST     AST1_1
# 9399             %        ...                32      AST     AST1_1
# 9454             %        ...                32      AST     AST1_1
# 9404             %        ...                37      AST     AST1_1
# 9395             %        ...                28      AST     AST1_1
# 9459             %        ...                37      AST     AST1_1
# 9453             %        ...                31      AST     AST1_1
# 9470             %        ...                49      AST     AST1_1
# 9415             %        ...                49      AST     AST1_1
# 9401             %        ...                34      AST     AST1_1
# 9456             %        ...                34      AST     AST1_1
# 9389             %        ...                22      AST     AST1_1
# 9398             %        ...                31      AST     AST1_1
# 9444             %        ...                22      AST     AST1_1
# ...            ...        ...               ...      ...        ...
# 9385             %        ...                18      AST     AST1_1
# 9447             %        ...                25      AST     AST1_1
# 9392             %        ...                25      AST     AST1_1
# 9471             %        ...                50      AST     AST1_1
# 9465             %        ...                44      AST     AST1_1
# 9377             %        ...                09      AST     AST1_1
# 9408             %        ...                41      AST     AST1_1
# 9432             %        ...                09      AST     AST1_1
# 9463             %        ...                41      AST     AST1_1
# 9409             %        ...                42      AST     AST1_1
# 9464             %        ...                42      AST     AST1_1
# 9382             %        ...                15      AST     AST1_1
# 9423             %        ...                72      AST     AST1_1
# 9437             %        ...                15      AST     AST1_1
# 9410             %        ...                44      AST     AST1_1
# 9478             %        ...                72      AST     AST1_1
# 9393             %        ...                26      AST     AST1_1
# 9413             %        ...                47      AST     AST1_1
# 9468             %        ...                47      AST     AST1_1
# 9448             %        ...                26      AST     AST1_1
# 9400             %        ...                33      AST     AST1_1
# 9443             %        ...                21      AST     AST1_1
# 9388             %        ...                21      AST     AST1_1
# 9402             %        ...                35      AST     AST1_1
# 9474             %        ...                54      AST     AST1_1
# 9419             %        ...                54      AST     AST1_1
# 9457             %        ...                35      AST     AST1_1
# 9455             %        ...                33      AST     AST1_1
# 9390             %        ...                23      AST     AST1_1
# 9445             %        ...                23      AST     AST1_1
#
#      DataValueTypeID StratificationCategoryID1 StratificationID1  \
# 9422         CRDPREV                   OVERALL               OVR
# 9477      AGEADJPREV                   OVERALL               OVR
# 9467      AGEADJPREV                   OVERALL               OVR
# 9412         CRDPREV                   OVERALL               OVR
# 9424         CRDPREV                   OVERALL               OVR
# 9479      AGEADJPREV                   OVERALL               OVR
# 9380         CRDPREV                   OVERALL               OVR
# 9435      AGEADJPREV                   OVERALL               OVR
# 9469      AGEADJPREV                   OVERALL               OVR
# 9414         CRDPREV                   OVERALL               OVR
# 9394         CRDPREV                   OVERALL               OVR
# 9449      AGEADJPREV                   OVERALL               OVR
# 9430      AGEADJPREV                   OVERALL               OVR
# 9375         CRDPREV                   OVERALL               OVR
# 9441      AGEADJPREV                   OVERALL               OVR
# 9386         CRDPREV                   OVERALL               OVR
# 9450      AGEADJPREV                   OVERALL               OVR
# 9399         CRDPREV                   OVERALL               OVR
# 9454      AGEADJPREV                   OVERALL               OVR
# 9404         CRDPREV                   OVERALL               OVR
# 9395         CRDPREV                   OVERALL               OVR
# 9459      AGEADJPREV                   OVERALL               OVR
# 9453      AGEADJPREV                   OVERALL               OVR
# 9470      AGEADJPREV                   OVERALL               OVR
# 9415         CRDPREV                   OVERALL               OVR
# 9401         CRDPREV                   OVERALL               OVR
# 9456      AGEADJPREV                   OVERALL               OVR
# 9389         CRDPREV                   OVERALL               OVR
# 9398         CRDPREV                   OVERALL               OVR
# 9444      AGEADJPREV                   OVERALL               OVR
# ...              ...                       ...               ...
# 9385         CRDPREV                   OVERALL               OVR
# 9447      AGEADJPREV                   OVERALL               OVR
# 9392         CRDPREV                   OVERALL               OVR
# 9471      AGEADJPREV                   OVERALL               OVR
# 9465      AGEADJPREV                   OVERALL               OVR
# 9377         CRDPREV                   OVERALL               OVR
# 9408         CRDPREV                   OVERALL               OVR
# 9432      AGEADJPREV                   OVERALL               OVR
# 9463      AGEADJPREV                   OVERALL               OVR
# 9409         CRDPREV                   OVERALL               OVR
# 9464      AGEADJPREV                   OVERALL               OVR
# 9382         CRDPREV                   OVERALL               OVR
# 9423         CRDPREV                   OVERALL               OVR
# 9437      AGEADJPREV                   OVERALL               OVR
# 9410         CRDPREV                   OVERALL               OVR
# 9478      AGEADJPREV                   OVERALL               OVR
# 9393         CRDPREV                   OVERALL               OVR
# 9413         CRDPREV                   OVERALL               OVR
# 9468      AGEADJPREV                   OVERALL               OVR
# 9448      AGEADJPREV                   OVERALL               OVR
# 9400         CRDPREV                   OVERALL               OVR
# 9443      AGEADJPREV                   OVERALL               OVR
# 9388         CRDPREV                   OVERALL               OVR
# 9402         CRDPREV                   OVERALL               OVR
# 9474      AGEADJPREV                   OVERALL               OVR
# 9419         CRDPREV                   OVERALL               OVR
# 9457      AGEADJPREV                   OVERALL               OVR
# 9455      AGEADJPREV                   OVERALL               OVR
# 9390         CRDPREV                   OVERALL               OVR
# 9445      AGEADJPREV                   OVERALL               OVR
#
#      StratificationCategoryID2 StratificationID2 StratificationCategoryID3  \
# 9422                      None              None                      None
# 9477                      None              None                      None
# 9467                      None              None                      None
# 9412                      None              None                      None
# 9424                      None              None                      None
# 9479                      None              None                      None
# 9380                      None              None                      None
# 9435                      None              None                      None
# 9469                      None              None                      None
# 9414                      None              None                      None
# 9394                      None              None                      None
# 9449                      None              None                      None
# 9430                      None              None                      None
# 9375                      None              None                      None
# 9441                      None              None                      None
# 9386                      None              None                      None
# 9450                      None              None                      None
# 9399                      None              None                      None
# 9454                      None              None                      None
# 9404                      None              None                      None
# 9395                      None              None                      None
# 9459                      None              None                      None
# 9453                      None              None                      None
# 9470                      None              None                      None
# 9415                      None              None                      None
# 9401                      None              None                      None
# 9456                      None              None                      None
# 9389                      None              None                      None
# 9398                      None              None                      None
# 9444                      None              None                      None
# ...                        ...               ...                       ...
# 9385                      None              None                      None
# 9447                      None              None                      None
# 9392                      None              None                      None
# 9471                      None              None                      None
# 9465                      None              None                      None
# 9377                      None              None                      None
# 9408                      None              None                      None
# 9432                      None              None                      None
# 9463                      None              None                      None
# 9409                      None              None                      None
# 9464                      None              None                      None
# 9382                      None              None                      None
# 9423                      None              None                      None
# 9437                      None              None                      None
# 9410                      None              None                      None
# 9478                      None              None                      None
# 9393                      None              None                      None
# 9413                      None              None                      None
# 9468                      None              None                      None
# 9448                      None              None                      None
# 9400                      None              None                      None
# 9443                      None              None                      None
# 9388                      None              None                      None
# 9402                      None              None                      None
# 9474                      None              None                      None
# 9419                      None              None                      None
# 9457                      None              None                      None
# 9455                      None              None                      None
# 9390                      None              None                      None
# 9445                      None              None                      None
#
#      StratificationID3
# 9422              None
# 9477              None
# 9467              None
# 9412              None
# 9424              None
# 9479              None
# 9380              None
# 9435              None
# 9469              None
# 9414              None
# 9394              None
# 9449              None
# 9430              None
# 9375              None
# 9441              None
# 9386              None
# 9450              None
# 9399              None
# 9454              None
# 9404              None
# 9395              None
# 9459              None
# 9453              None
# 9470              None
# 9415              None
# 9401              None
# 9456              None
# 9389              None
# 9398              None
# 9444              None
# ...                ...
# 9385              None
# 9447              None
# 9392              None
# 9471              None
# 9465              None
# 9377              None
# 9408              None
# 9432              None
# 9463              None
# 9409              None
# 9464              None
# 9382              None
# 9423              None
# 9437              None
# 9410              None
# 9478              None
# 9393              None
# 9413              None
# 9468              None
# 9448              None
# 9400              None
# 9443              None
# 9388              None
# 9402              None
# 9474              None
# 9419              None
# 9457              None
# 9455              None
# 9390              None
# 9445              None
#
# [110 rows x 35 columns]

# %%
values = []
for n in range(0,len(df)):
    try:
        values.append(float(df['DataValue'][n]))
    except:
        values.append(0)

df['DataValue']= values
df['DataValue'][1]
# Out:
# 13.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.barplot(x="LocationAbbr", y="DataValue", 
            data=df[(df['Topic']=='Asthma')&
                    (df['Question']=='Current asthma prevalence among adults aged >= 18 years')
                   &(df['StratificationCategoryID1']=='OVERALL')].sort_values(by = ['DataValue']))
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# TypeErrorTraceback (most recent call last)
# <ipython-input-56-c264f226d5cf> in <module>()
#       7                     (df['Question']=='Current asthma prevalence among adults aged >= 18 years')
#       8                    &(df['StratificationCategoryID1']=='OVERALL')].sort_values(by = ['DataValue']),
# ----> 9            height=10)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3152         ax = plt.gca()
#    3153
# -> 3154     plotter.plot(ax, kwargs)
#    3155     return ax
#    3156
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/seaborn/categorical.py in plot(self, ax, bar_kws)
#    1659     def plot(self, ax, bar_kws):
#    1660         """Make the plot."""
# -> 1661         self.draw_bars(ax, bar_kws)
#    1662         self.annotate_axes(ax)
#    1663         if self.orient == "h":
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/seaborn/categorical.py in draw_bars(self, ax, kws)
#    1625             # Draw the bars
#    1626             barfunc(barpos, self.statistic, self.width,
# -> 1627                     color=self.colors, align="center", **kws)
#    1628
#    1629             # Draw the confidence intervals
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# TypeError: bar() got multiple values for argument 'height'

# %%
view.DataValue = view.DataValue.astype(float)
view = view.sort_values(by='DataValue')
view.set_index('LocationAbbr')['DataValue'].plot(kind='bar', figsize=(10,10))
plt.title('Asthma Rates by State 2016')
plt.ylabel('Percent 18+ with Asthma')
plt.xlabel('State')
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-51-5b540f2cb5fc> in <module>()
# ----> 1 view.DataValue = view.DataValue.astype(float)
#       2 view = view.sort_values(by='DataValue')
#       3 view.set_index('LocationAbbr')['DataValue'].plot(kind='bar', figsize=(10,10))
#       4 plt.title('Asthma Rates by State 2016')
#       5 plt.ylabel('Percent 18+ with Asthma')
#
# NameError: name 'view' is not defined

# %% [markdown]
# ## Level-Up!
# ## Create a function (or class) that returns an outline of the schema structure like this:
# <img src="images/outline.jpg" width="350">
#
# Rules:
# * Your outline should follow the numbering outline above (I, A, 1, a, i).
# * Your outline should be properly indented! (Four spaces or one tab per indentation level.)
# * Your function goes to at least a depth of 5 (Level-up: create a parameter so that the user can specify this)
# * If an entry is a dictionary, list its keys as the subheadings
# * After listing a key name (where applicable) include a space, a dash and the data type of the entry
# * If an entry is a dict or list put in parentheses how many items are in the entry
# * lists will not have key names for their entries (they're just indexed)
# * For subheadings of a list, state their datatypes.
# * If a dictionary or list is more then 5 items long, only show the first 5 (we want to limit our previews); make an arbitrary order choice for dictionaries. (Level-up: Parallel to above; allow user to specify number of items to preview for large subheading collections.)

# %%
# Your code here; you will probably want to define subfunctions.
def print_obj_outline(json_obj):
    return outline

# %%
outline = print_obj_outline(data)

# %%
print(outline) #Your function should produce the following output for this json object (and work for all json files!)
# Out:
# I. root - <class 'dict'> (2 items)
#     A. meta <class 'dict'> (1 items)
#         1. view <class 'dict'> (40 items)
#             a. id <class 'str'>
#             b. name <class 'str'>
#             c. attribution <class 'str'>
#             d. attributionLink <class 'str'>
#             e. averageRating <class 'int'>
#     B. data <class 'list'> (60266 items)
#         1. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         2. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         3. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         4. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         5. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>

# %% [markdown]
# ## Summary
#
# Well done! In this lab you got some extended practice exploring the structure of JSON files and writing a recursive generalized function for outlining a JSON file's schema!
